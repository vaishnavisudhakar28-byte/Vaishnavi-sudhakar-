# %%
#Display recorded crop yield
def display_yield(yield_value):
    for crop, yield_value in yields.items():
        print(f"field: {field_number}, Yield: {yield_value}")

# %%
def average_yield(yields):
    total = 0
    for yield_item in yields:
        total += yield_item
    if len(yields) == 0:
        return 0
    average_yield_value = total / len(yields)
    return average_yield_value

# %%
def get_crop_yields_for_fields(field_number):
