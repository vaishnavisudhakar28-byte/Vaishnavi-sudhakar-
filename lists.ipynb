# %%
def greet(year):
 print("happy New Year",year)

# %%
greet(2026)
# Out:
# happy New Year 2026

# %%
thislist=["apple","banana","mango"]
print(len(thislist))
# Out:
# 3

# %%
list1=["apple","mango","guava"]
list2=[1,2,3]
list3=[True,False,True]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'mango', 'guava']
# [1, 2, 3]
# [True, False, True]

# %%
list1=["apple","mango","guava"]
list2=[1,2,3]
list3=[True,False,True]
print(list1)
print(list2)
print(list3)
print(len(list1))
print(len(list2))
print(len(list3))
# Out:
# ['apple', 'mango', 'guava']
# [1, 2, 3]
# [True, False, True]
# 3
# 3
# 3

# %%
for item in range(len(list1)):
    print([item])
# Out:
# [0]
# [1]
# [2]

# %%
for item in range(len(list1)):
    print(list1[item])
# Out:
# apple
# mango
# guava

# %%
mylist=["apple","banana","muskmelon"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
mylist=["apple","banana","muskmelon"]
print(type(mylist))
print(type(list1))
print(type(list2))
print(type(list3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
thislist2=list(("apple","banana","muskmelon"))
print(thislist2)
# Out:
# ['apple', 'banana', 'muskmelon']

# %%
print(thislist[1])
print(thislist[2])
# Out:
# banana
# mango

# %%
print(thislist[-1])
print(thislist[-2])
print(thislist[-3])
# Out:
# mango
# banana
# apple

# %%
thislist3=("apple","guava","banana","muskmelon","cherry","jack","fig")
print(thislist3[2:5])
# Out:
# ('banana', 'muskmelon', 'cherry')

# %%
thislist3=["apple","guava","banana","muskmelon","cherry","jack","fig"]
print(thislist3[-7:-4])
# Out:
# ['apple', 'guava', 'banana']

# %%
thislist3=["apple","guava","banana","muskmelon","cherry","jack","fig"]
print(thislist3[-7:])
# Out:
# ['apple', 'guava', 'banana', 'muskmelon', 'cherry', 'jack', 'fig']

# %%
thislist3=["apple","guava","banana","muskmelon","cherry","jack","fig"]
print(thislist3[:-4])
# Out:
# ['apple', 'guava', 'banana']

# %%
if "apple" in thislist3:
    print("yes,'apple' is in the fruits list")
# Out:
# yes,'apple' is in the fruits list

# %%
list=["apple","banana","muskmelon"]

# %%
thislist[1]="sapota"
print(thislist)
# Out:
# ['apple', 'sapota', 'mango']

# %%
thislist4=["apple","banana","muskmelon","kiwi"]
thislist4[1:3]=["sapota","cherry"]
print(thislist4)
# Out:
# ['apple', 'sapota', 'cherry', 'kiwi']

# %%
thislist4=["apple","banana","muskmelon","kiwi"]
thislist4[1:1]=["sapota"]
print(thislist4)
# Out:
# ['apple', 'sapota', 'banana', 'muskmelon', 'kiwi']

# %% [markdown]
# thislist[1:3]=["jackfruit"]
# print(thislist)

# %%
thislist5=["apple","banana","muskmelon","kiwi"]
thislist.insert(2,"watermelon")
print(thislist)
# Out:
# ['apple', 'jackfruit', 'watermelon', 'watermelon', 'watermelon', 'watermelon', 'watermelon', 'watermelon', 'watermelon', 'watermelon']

# %%
thislist=["apple","cherry","mango"]
thislist.append("jackfruit")
print(thislist)
# Out:
# ['apple', 'cherry', 'mango', 'jackfruit']

# %%
tropical=["mango","pineapple","papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'cherry', 'mango', 'jackfruit', 'mango', 'pineapple', 'papaya']

# %%
thislist.remove("mango")
print(thislist)
# Out:
# ['apple', 'cherry', 'jackfruit', 'pineapple', 'papaya']

# %%
thislist=["apple","cherry","mango"]
del (thislist[0])
print(thislist)
# Out:
# ['cherry', 'mango']

# %% [markdown]
# thislist.clear()
# print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
[print(x)for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
def show_message():
  print("hello")

# %%
value=show_message()
print(value)
# Out:
# hello
# None

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse=True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
newlist = list(thislist)
print(newlist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
mylist = thislist[-3:-1]
print(mylist)
# Out:
# ['apple', 'banana']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
