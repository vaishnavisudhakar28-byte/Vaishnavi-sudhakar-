# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-5:-3])
# Out:
# ('cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-3:])
# Out:
# ('kiwi', 'melon', 'mango')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:])
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
if "jack" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
else:
  print("No, 'apple' is not in the fruits tuple")
# Out:
# No, 'apple' is not in the fruits tuple

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)

thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')
# ('apple', 'banana', 'cherry', 'orange', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple

# %%
print(thistuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2776548823.py in <cell line: 0>()
# ----> 1 print(thistuple)
#
# NameError: name 'thistuple' is not defined

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry")

(c1,c2,c3) = fruits

print(c1)
print(c2)
print(c3)
# Out:
# apple
# banana
# cherry

# %%
citric_fruits = ("orange", "lemon", "grapefruit","tangerine", "gooseberry")
(green, yellow, *red) = citric_fruits

print(green)
print(yellow)
print(red)
# Out:
# orange
# lemon
# ['grapefruit', 'tangerine', 'gooseberry']

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
thistuple=(1,3,7,8,7,5,4,8,6,8,5)
x=thistuple.count("")
y=thistuple.index(8,8)
z=thistuple.count(8)
a=thistuple.index(7)
print(x)
print(y)
print(z)
print(a)
# Out:
# 0
# 9
# 5
# 2

# %%
thistuple=[10,20,30,40,50]
print (thistuple[:])
# Out:
# [10, 20, 30, 40, 50]

# %%
thistuple=[10,20,30,40,50]
print (thistuple[::])
# Out:
# [10, 20, 30, 40, 50]

# %%
thistuple=[10,20,30,40,50]
print (thistuple[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
thistuple=[10,20,30,40,50]
print (thistuple[::2])
# Out:
# [10, 30, 50]

# %%
number=(5,10,15)
print(min(number))
print(max(number))
print(sum(number))
# Out:
# 5
# 15
# 30
